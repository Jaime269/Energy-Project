# %%
#a)load basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#Plot styling
import seaborn as sns; sns.set() 

import statistics
import matplotlib.pyplot as plt
from matplotlib import rc

# %% [markdown]
# [1. Create an api caller for BMRS Imbalance Prices (B1770) and Aggregated Imbalance Volumes (B1780)](#LoadDataset)
#
# [2. Clean the inputs and produce two half hourly time series](#Cleantheinputs)
#
# [3. Generate a message that provides the total daily imbalance cost and the daily imbalance unit rate.](#Generateamessage)
#
# [4. Report which Hour had the highest absolute imbalance volumes.](#Report)
#
# [5. Extra analysis or plotting will be appreciated.](#Extraanalysis)

# %% [markdown]
# # <a id='LoadDataset'></a> 1 Create an api caller
#
# We load the data from a URL link in format CSV file

# %%
First_period=1
Last_period=49
col_names=['Time Series ID','Business Type','Control Area','Settlement Date','Settlement Period','Imbalance Quantity (MAW)','Curve Type','Resolution','Document Type','Process Type','Active Flag','Document Status','Document ID','Document RevNum','Imbalance Quantity Direction']
combined_B1780 = pd.DataFrame(columns=col_names)
#combined_dh=[[]]
a=1
date = input ('which date do you want to retrieve the data? (format:yyyy-mm-dd)')
for a in range(First_period, Last_period):
    url=('https://api.bmreports.com/BMRS/B1780/V1?ServiceType=csv&Period='+ str(a)+'&APIKey=tt5u02r3keivv4f&SettlementDate='+ str(date))
    #col_names=['*Time Series ID','Business Type','Control Area','Settlement Date','Settlement Period','Imbalance Quantity (MAW)','Curve Type','Resolution','Document Type','Process Type','Active Flag','Document Status','Document ID','Document RevNum','Imbalance Quantity Direction']
    dh = pd.read_csv(url, names=col_names)
    N = 5
    dh1 = dh.iloc[N: , :]
    dh1 = dh1.iloc[:1 , :]
    dh1.reset_index(inplace=True, drop=True)
    combined_B1780 = pd.concat([combined_B1780, dh1])
    #combined_dh=combined_dh.append(dh1,sort=False)
# Out:
# which date do you want to retrieve the data? (format:yyyy-mm-dd)2022-07-01

# %%
combined_B1780.reset_index(inplace=True,drop=True)
combined_B1780
# Out:
#           Time Series ID             Business Type      Control Area  \
# 0   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 1   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 2   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 3   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 4   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 5   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 6   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 7   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 8   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 9   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 10  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 11  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 12  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 13  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 14  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 15  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 16  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 17  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 18  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 19  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 20  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 21  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 22  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 23  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 24  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 25  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 26  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 27  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 28  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 29  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 30  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 31  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 32  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 33  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 34  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 35  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 36  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 37  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 38  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 39  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 40  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 41  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 42  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 43  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 44  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 45  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 46  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 47  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
#
#    Settlement Date Settlement Period Imbalance Quantity (MAW)  \
# 0       2022-07-01                 1                 497.2796
# 1       2022-07-01                 2                  269.111
# 2       2022-07-01                 3                 285.8971
# 3       2022-07-01                 4                 236.7084
# 4       2022-07-01                 5                  -32.175
# 5       2022-07-01                 6                -101.1726
# 6       2022-07-01                 7                  17.1079
# 7       2022-07-01                 8                  58.9144
# 8       2022-07-01                 9                 373.2183
# 9       2022-07-01                10                 163.3287
# 10      2022-07-01                11                 -34.7279
# 11      2022-07-01                12                 -12.2331
# 12      2022-07-01                13                 156.4757
# 13      2022-07-01                14                 192.2541
# 14      2022-07-01                15                 163.9739
# 15      2022-07-01                16                  378.023
# 46                      SURPLUS
# 47                      SURPLUS

# %%
combined_B1780v1=combined_B1780

# %%
First_period=1
Last_period=49
col_names=['DocumentID','DocumentRevNum','ActiveFlag','ProcessType','DocumentType','Resolution','CurveType','PriceCategory','ImbalancePriceAmount','SettlementPeriod','SettlementDate','ControlArea','BusinessType','TimeSeriesID','DocumentStatus']
#combined_B1770=[[]]
combined_B1770 = pd.DataFrame(columns=col_names)

i=1
for i in range(First_period, Last_period):
    url=('https://api.bmreports.com/BMRS/B1770/V1?ServiceType=csv&Period='+ str(i)+'&APIKey=tt5u02r3keivv4f&SettlementDate='+ str(date))
    #col_names=['*Time Series ID','Business Type','Control Area','Settlement Date','Settlement Period','Imbalance Quantity (MAW)','Curve Type','Resolution','Document Type','Process Type','Active Flag','Document Status','Document ID','Document RevNum','Imbalance Quantity Direction']
    df = pd.read_csv(url, names=col_names)
    N = 5
    df1 = df.iloc[N: , :]
    df1 = df1.iloc[:2 , :]
    df1.reset_index(inplace=True, drop=True)
    combined_B1770 = pd.concat([combined_B1770, df1])
    #combined_dh=combined_dh.append(dh1,sort=False)

# %%
combined_B1770.reset_index(inplace=True,drop=True)
combined_B1770
# Out:
#                  DocumentID DocumentRevNum ActiveFlag ProcessType  \
# 0   ELX-EMFIP-IMBP-29543245              1          Y    Realised
# 1   ELX-EMFIP-IMBP-29543245              1          Y    Realised
# 2   ELX-EMFIP-IMBP-29543379              1          Y    Realised
# 3   ELX-EMFIP-IMBP-29543379              1          Y    Realised
# 4   ELX-EMFIP-IMBP-29543453              1          Y    Realised
# ..                      ...            ...        ...         ...
# 91  ELX-EMFIP-IMBP-29550218              1          Y    Realised
# 92  ELX-EMFIP-IMBP-29550381              1          Y    Realised
# 93  ELX-EMFIP-IMBP-29550381              1          Y    Realised
# 94  ELX-EMFIP-IMBP-29550518              1          Y    Realised
# 95  ELX-EMFIP-IMBP-29550518              1          Y    Realised
#
#         DocumentType Resolution                    CurveType  \
# 0   Imbalance prices      PT30M  Sequential fixed size block
# 1   Imbalance prices      PT30M  Sequential fixed size block
# 2   Imbalance prices      PT30M  Sequential fixed size block
# 3   Imbalance prices      PT30M  Sequential fixed size block
# 4   Imbalance prices      PT30M  Sequential fixed size block
# ..               ...        ...                          ...
# 91  Imbalance prices      PT30M  Sequential fixed size block
# 92  Imbalance prices      PT30M  Sequential fixed size block
# 93  Imbalance prices      PT30M  Sequential fixed size block
# 94  Imbalance prices      PT30M  Sequential fixed size block
# 95  Imbalance prices      PT30M  Sequential fixed size block
#
#            PriceCategory ImbalancePriceAmount SettlementPeriod SettlementDate  \
# 0   Insufficient balance                  285                1     2022-07-01
# 1         Excess balance                  285                1     2022-07-01
# 2   Insufficient balance                  284                2     2022-07-01
# 3         Excess balance                  284                2     2022-07-01
# 4   Insufficient balance                  284                3     2022-07-01
# ..                   ...                  ...              ...            ...
# 91        Excess balance               281.08               46     2022-07-01
# 92  Insufficient balance                  205               47     2022-07-01
# 93        Excess balance                  205               47     2022-07-01
# 94  Insufficient balance                  200               48     2022-07-01
# 95        Excess balance                  200               48     2022-07-01
#
#          ControlArea              BusinessType         TimeSeriesID  \
# 0   10YGB----------A  Balance energy deviation  ELX-EMFIP-IMBP-TS-1
# 1   10YGB----------A  Balance energy deviation  ELX-EMFIP-IMBP-TS-2
# 2   10YGB----------A  Balance energy deviation  ELX-EMFIP-IMBP-TS-1
# 3   10YGB----------A  Balance energy deviation  ELX-EMFIP-IMBP-TS-2
# 4   10YGB----------A  Balance energy deviation  ELX-EMFIP-IMBP-TS-1
# ..               ...                       ...                  ...
# 91  10YGB----------A  Balance energy deviation  ELX-EMFIP-IMBP-TS-2
# 92  10YGB----------A  Balance energy deviation  ELX-EMFIP-IMBP-TS-1
# 93  10YGB----------A  Balance energy deviation  ELX-EMFIP-IMBP-TS-2
# 94  10YGB----------A  Balance energy deviation  ELX-EMFIP-IMBP-TS-1
# 95  10YGB----------A  Balance energy deviation  ELX-EMFIP-IMBP-TS-2
#
#    DocumentStatus
# 0           Final
# 1           Final
# 2           Final
# 3           Final
# 4           Final
# ..            ...
# 91          Final
# 92          Final
# 93          Final
# 94          Final
# 95          Final
#
# [96 rows x 15 columns]

# %%
combined_B1770v1=combined_B1770

# %% [markdown]
# # <a id='Cleantheinputs'></a> 2. Clean the inputs and produce two half hourly time series

# %% [markdown]
# ### We remove the blank spaces in the columns headers

# %%
combined_B1770v1.columns = combined_B1770v1.columns.str.replace(' ','')
combined_B1780v1.columns = combined_B1780v1.columns.str.replace(' ','')

# %%
combined_B1770v1.columns
# Out:
# Index(['DocumentID', 'DocumentRevNum', 'ActiveFlag', 'ProcessType',
#        'DocumentType', 'Resolution', 'CurveType', 'PriceCategory',
#        'ImbalancePriceAmount', 'SettlementPeriod', 'SettlementDate',
#        'ControlArea', 'BusinessType', 'TimeSeriesID', 'DocumentStatus'],
#       dtype='object')

# %%
combined_B1780v1.columns
# Out:
# Index(['TimeSeriesID', 'BusinessType', 'ControlArea', 'SettlementDate',
#        'SettlementPeriod', 'ImbalanceQuantity(MAW)', 'CurveType', 'Resolution',
#        'DocumentType', 'ProcessType', 'ActiveFlag', 'DocumentStatus',
#        'DocumentID', 'DocumentRevNum', 'ImbalanceQuantityDirection'],
#       dtype='object')

# %% [markdown]
# ### Change the dtype of both datasets

# %%
combined_B1770v1.dtypes
# Out:
# DocumentID              object
# DocumentRevNum          object
# ActiveFlag              object
# ProcessType             object
# DocumentType            object
# Resolution              object
# CurveType               object
# PriceCategory           object
# ImbalancePriceAmount    object
# SettlementPeriod        object
# SettlementDate          object
# ControlArea             object
# BusinessType            object
# TimeSeriesID            object
# DocumentStatus          object
# dtype: object

# %%
combined_B1770v1 = combined_B1770v1.astype({"DocumentRevNum":'int', "ImbalancePriceAmount":'float', "SettlementPeriod":'float', "SettlementDate":'datetime64[ns]'}) 
combined_B1770v1.dtypes
# Out:
# DocumentID                      object
# DocumentRevNum                   int32
# ActiveFlag                      object
# ProcessType                     object
# DocumentType                    object
# Resolution                      object
# CurveType                       object
# PriceCategory                   object
# ImbalancePriceAmount           float64
# SettlementPeriod               float64
# SettlementDate          datetime64[ns]
# ControlArea                     object
# BusinessType                    object
# TimeSeriesID                    object
# DocumentStatus                  object
# dtype: object

# %%
combined_B1780v1.dtypes
# Out:
# TimeSeriesID                  object
# BusinessType                  object
# ControlArea                   object
# SettlementDate                object
# SettlementPeriod              object
# ImbalanceQuantity(MAW)        object
# CurveType                     object
# Resolution                    object
# DocumentType                  object
# ProcessType                   object
# ActiveFlag                    object
# DocumentStatus                object
# DocumentID                    object
# DocumentRevNum                object
# ImbalanceQuantityDirection    object
# dtype: object

# %%
combined_B1780v1 = combined_B1780v1.astype({"SettlementPeriod":'int', "DocumentRevNum":'int', "ImbalanceQuantity(MAW)":'float', "SettlementDate":'datetime64[ns]'}) 
combined_B1780v1.dtypes
# Out:
# TimeSeriesID                          object
# BusinessType                          object
# ControlArea                           object
# SettlementDate                datetime64[ns]
# SettlementPeriod                       int32
# ImbalanceQuantity(MAW)               float64
# CurveType                             object
# Resolution                            object
# DocumentType                          object
# ProcessType                           object
# ActiveFlag                            object
# DocumentStatus                        object
# DocumentID                            object
# DocumentRevNum                         int32
# ImbalanceQuantityDirection            object
# dtype: object

# %% [markdown]
# ### Ensure all the dataset is in the desired order

# %%
combined_B1780v1.sort_values(by=['SettlementPeriod','SettlementDate'],ascending=True, inplace=True)

# %%
combined_B1780v1.reset_index(inplace=True, drop=True)
combined_B1780v1
# Out:
#             TimeSeriesID              BusinessType       ControlArea  \
# 0   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 1   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 2   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 3   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 4   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 5   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 6   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 7   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 8   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 9   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 10  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 11  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 12  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 13  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 14  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 15  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 16  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 17  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 18  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 19  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 20  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 21  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 22  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 23  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 24  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 25  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 26  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 27  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 28  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 29  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 30  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 31  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 32  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 33  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 34  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 35  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 36  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 37  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 38  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 39  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 40  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 41  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 42  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 43  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 44  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 45  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 46  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 47  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
#
#    SettlementDate  SettlementPeriod  ImbalanceQuantity(MAW)  \
# 0      2022-07-01                 1                497.2796
# 1      2022-07-01                 2                269.1110
# 2      2022-07-01                 3                285.8971
# 3      2022-07-01                 4                236.7084
# 4      2022-07-01                 5                -32.1750
# 5      2022-07-01                 6               -101.1726
# 6      2022-07-01                 7                 17.1079
# 7      2022-07-01                 8                 58.9144
# 8      2022-07-01                 9                373.2183
# 9      2022-07-01                10                163.3287
# 10     2022-07-01                11                -34.7279
# 11     2022-07-01                12                -12.2331
# 12     2022-07-01                13                156.4757
# 13     2022-07-01                14                192.2541
# 14     2022-07-01                15                163.9739
# 15     2022-07-01                16                378.0230
# 16     2022-07-01                17                211.5986
# 17     2022-07-01                18                 62.2386
# 18     2022-07-01                19                 70.5605
# 19     2022-07-01                20                 11.3604
# 20     2022-07-01                21                 91.1258
# 21     2022-07-01                22                -13.2968
# 22     2022-07-01                23                 65.8256
# 23     2022-07-01                24                 15.8280
# 24     2022-07-01                25                -90.7583
# 25     2022-07-01                26                -27.1934
# 26     2022-07-01                27                 47.8435
# 27     2022-07-01                28                 61.0209
# 28     2022-07-01                29                 93.2949
# 29     2022-07-01                30               -298.6518
# 30     2022-07-01                31                 64.2674
# 31     2022-07-01                32                  7.8939
# 32     2022-07-01                33                 46.0023
# 33     2022-07-01                34               -136.2798
# 34     2022-07-01                35               -217.0414
# 35     2022-07-01                36               -183.4182
# 36     2022-07-01                37                 15.0352
# 37     2022-07-01                38                187.0221
# 38     2022-07-01                39                146.5405
# 39     2022-07-01                40                352.7744
# 40     2022-07-01                41                -52.8972
# 41     2022-07-01                42                 81.4541
# 42     2022-07-01                43                153.0919
# 43     2022-07-01                44                 93.3378
# 44     2022-07-01                45                168.8522
# 45     2022-07-01                46                 55.6084
# 46     2022-07-01                47                134.7415
# 47     2022-07-01                48                 36.4483
#
#                       CurveType Resolution      DocumentType ProcessType  \
# 0   Sequential fixed size block      PT30M  Imbalance volume    Realised
#
# 36          Y          Final  ELX-EMFIP-AIMBV-29548712               1
# 37          Y          Final  ELX-EMFIP-AIMBV-29548900               1
# 38          Y          Final  ELX-EMFIP-AIMBV-29549019               1
# 39          Y          Final  ELX-EMFIP-AIMBV-29549167               1
# 40          Y          Final  ELX-EMFIP-AIMBV-29549285               1
# 41          Y          Final  ELX-EMFIP-AIMBV-29549462               1
# 42          Y          Final  ELX-EMFIP-AIMBV-29549669               1
# 43          Y          Final  ELX-EMFIP-AIMBV-29549906               1
# 44          Y          Final  ELX-EMFIP-AIMBV-29550053               1
# 45          Y          Final  ELX-EMFIP-AIMBV-29550217               1
# 46          Y          Final  ELX-EMFIP-AIMBV-29550382               1
# 47          Y          Final  ELX-EMFIP-AIMBV-29550517               1
#
#    ImbalanceQuantityDirection
# 0                     SURPLUS
# 1                     SURPLUS
# 2                     SURPLUS
# 3                     SURPLUS
# 4                     DEFICIT
# 5                     DEFICIT
# 6                     SURPLUS
# 7                     SURPLUS
# 8                     SURPLUS
# 9                     SURPLUS
# 10                    DEFICIT
# 11                    DEFICIT
# 12                    SURPLUS
# 13                    SURPLUS
# 14                    SURPLUS
# 15                    SURPLUS
# 16                    SURPLUS
# 17                    SURPLUS
# 18                    SURPLUS
# 19                    SURPLUS
# 20                    SURPLUS
# 21                    DEFICIT
# 22                    SURPLUS
# 23                    SURPLUS
# 24                    DEFICIT
# 25                    DEFICIT
# 26                    SURPLUS
# 27                    SURPLUS
# 28                    SURPLUS
# 29                    DEFICIT
# 30                    SURPLUS
# 31                    SURPLUS
# 32                    SURPLUS
# 33                    DEFICIT
# 34                    DEFICIT
# 35                    DEFICIT
# 36                    SURPLUS
# 37                    SURPLUS
# 38                    SURPLUS
# 39                    SURPLUS
# 40                    DEFICIT
# 41                    SURPLUS
# 42                    SURPLUS
# 43                    SURPLUS
# 44                    SURPLUS
# 45                    SURPLUS
# 46                    SURPLUS
# 47                    SURPLUS

# %%
combined_B1770v1.sort_values(by=['SettlementPeriod','SettlementDate','PriceCategory'], inplace=True)

# %%
combined_B1770v1.reset_index(inplace=True, drop=True)
combined_B1770v1
# Out:
#                  DocumentID  DocumentRevNum ActiveFlag ProcessType  \
# 0   ELX-EMFIP-IMBP-29543245               1          Y    Realised
# 1   ELX-EMFIP-IMBP-29543245               1          Y    Realised
# 2   ELX-EMFIP-IMBP-29543379               1          Y    Realised
# 3   ELX-EMFIP-IMBP-29543379               1          Y    Realised
# 4   ELX-EMFIP-IMBP-29543453               1          Y    Realised
# ..                      ...             ...        ...         ...
# 91  ELX-EMFIP-IMBP-29550218               1          Y    Realised
# 92  ELX-EMFIP-IMBP-29550381               1          Y    Realised
# 93  ELX-EMFIP-IMBP-29550381               1          Y    Realised
# 94  ELX-EMFIP-IMBP-29550518               1          Y    Realised
# 95  ELX-EMFIP-IMBP-29550518               1          Y    Realised
#
#         DocumentType Resolution                    CurveType  \
# 0   Imbalance prices      PT30M  Sequential fixed size block
# 1   Imbalance prices      PT30M  Sequential fixed size block
# 2   Imbalance prices      PT30M  Sequential fixed size block
# 3   Imbalance prices      PT30M  Sequential fixed size block
# 4   Imbalance prices      PT30M  Sequential fixed size block
# ..               ...        ...                          ...
# 91  Imbalance prices      PT30M  Sequential fixed size block
# 92  Imbalance prices      PT30M  Sequential fixed size block
# 93  Imbalance prices      PT30M  Sequential fixed size block
# 94  Imbalance prices      PT30M  Sequential fixed size block
# 95  Imbalance prices      PT30M  Sequential fixed size block
#
#            PriceCategory  ImbalancePriceAmount  SettlementPeriod  \
# 0         Excess balance                285.00               1.0
# 1   Insufficient balance                285.00               1.0
# 2         Excess balance                284.00               2.0
# 3   Insufficient balance                284.00               2.0
# 4         Excess balance                284.00               3.0
# ..                   ...                   ...               ...
# 91  Insufficient balance                281.08              46.0
# 92        Excess balance                205.00              47.0
# 93  Insufficient balance                205.00              47.0
# 94        Excess balance                200.00              48.0
# 95  Insufficient balance                200.00              48.0
#
#    SettlementDate       ControlArea              BusinessType  \
# 0      2022-07-01  10YGB----------A  Balance energy deviation
# 1      2022-07-01  10YGB----------A  Balance energy deviation
# 2      2022-07-01  10YGB----------A  Balance energy deviation
# 3      2022-07-01  10YGB----------A  Balance energy deviation
# 4      2022-07-01  10YGB----------A  Balance energy deviation
# ..            ...               ...                       ...
# 91     2022-07-01  10YGB----------A  Balance energy deviation
# 92     2022-07-01  10YGB----------A  Balance energy deviation
# 93     2022-07-01  10YGB----------A  Balance energy deviation
# 94     2022-07-01  10YGB----------A  Balance energy deviation
# 95     2022-07-01  10YGB----------A  Balance energy deviation
#
#            TimeSeriesID DocumentStatus
# 0   ELX-EMFIP-IMBP-TS-2          Final
# 1   ELX-EMFIP-IMBP-TS-1          Final
# 2   ELX-EMFIP-IMBP-TS-2          Final
# 3   ELX-EMFIP-IMBP-TS-1          Final
# 4   ELX-EMFIP-IMBP-TS-2          Final
# ..                  ...            ...
# 91  ELX-EMFIP-IMBP-TS-1          Final
# 92  ELX-EMFIP-IMBP-TS-2          Final
# 93  ELX-EMFIP-IMBP-TS-1          Final
# 94  ELX-EMFIP-IMBP-TS-2          Final
# 95  ELX-EMFIP-IMBP-TS-1          Final
#
# [96 rows x 15 columns]

# %%
combined_B1780v1.describe()
# Out:
#        SettlementPeriod  ImbalanceQuantity(MAW)  DocumentRevNum
# count             48.00               48.000000            48.0
# mean              24.50               80.546112             1.0
# std               14.00              154.285801             0.0
# min                1.00             -298.651800             1.0
# 25%               12.75                2.862150             1.0
# 50%               24.50               63.253000             1.0
# 75%               36.25              163.490000             1.0
# max               48.00              497.279600             1.0

# %%
combined_B1770v1.describe()
# Out:
#        DocumentRevNum  ImbalancePriceAmount  SettlementPeriod
# count            96.0             96.000000         96.000000
# mean              1.0            250.017098         24.500000
# std               0.0             77.645560         13.926121
# min               1.0            127.950300          1.000000
# 25%               1.0            182.502500         12.750000
# 50%               1.0            284.000000         24.500000
# 75%               1.0            305.462500         36.250000
# max               1.0            362.000000         48.000000

# %% [markdown]
# ### Link tables into one table

# %%
combined_B1780B1770=combined_B1780v1

# %%
combined_B1780B1770['Insufficient_balance_Price_Amount']=combined_B1770v1['ImbalancePriceAmount'][combined_B1770v1['PriceCategory'] == 'Insufficient balance'].reset_index(drop=True)
combined_B1780B1770
# Out:
#             TimeSeriesID              BusinessType       ControlArea  \
# 0   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
#
# 47          Y          Final  ELX-EMFIP-AIMBV-29550517               1
#
#    ImbalanceQuantityDirection  Insufficient_balance_Price_Amount
# 0                     SURPLUS                           285.0000
# 1                     SURPLUS                           284.0000
# 2                     SURPLUS                           284.0000
# 3                     SURPLUS                           284.0000
# 4                     DEFICIT                           133.0000
# 5                     DEFICIT                           132.7500
# 6                     SURPLUS                           250.0000
# 7                     SURPLUS                           275.0000
# 8                     SURPLUS                           284.0000
# 9                     SURPLUS                           275.0000
# 10                    DEFICIT                           129.0000
# 11                    DEFICIT                           127.9503
# 12                    SURPLUS                           324.3800
# 13                    SURPLUS                           326.9600
# 14                    SURPLUS                           342.9500
# 15                    SURPLUS                           346.4700
# 16                    SURPLUS                           328.0600
# 17                    SURPLUS                           319.3600
# 18                    SURPLUS                           305.0000
# 19                    SURPLUS                           303.4100
# 20                    SURPLUS                           303.4100
# 21                    DEFICIT                           137.0000
# 22                    SURPLUS                           362.0000
# 23                    SURPLUS                           324.4600
# 24                    DEFICIT                           133.3000
# 25                    DEFICIT                           133.3000
# 26                    SURPLUS                           278.0000
# 27                    SURPLUS                           331.0200
# 28                    SURPLUS                           309.6000
# 29                    DEFICIT                           129.0000
# 30                    SURPLUS                           200.3300
# 31                    SURPLUS                           197.6700
# 32                    SURPLUS                           220.7100
# 33                    DEFICIT                           131.5000
# 34                    DEFICIT                           130.0000
# 35                    DEFICIT                           130.0000
# 36                    SURPLUS                           286.7500
# 37                    SURPLUS                           290.5500
# 38                    SURPLUS                           304.2600
# 39                    SURPLUS                           306.8500
# 40                    DEFICIT                           130.0000
# 41                    SURPLUS                           288.9600
# 42                    SURPLUS                           299.4800
# 43                    SURPLUS                           286.6100
# 44                    SURPLUS                           329.6904
# 45                    SURPLUS                           281.0800
# 46                    SURPLUS                           205.0000
# 47                    SURPLUS                           200.0000

# %%
combined_B1780B1770['Excess_balance_Price_Amount']=combined_B1770v1['ImbalancePriceAmount'][combined_B1770v1['PriceCategory'] == 'Excess balance'].reset_index(drop=True)
combined_B1780B1770
# Out:
#             TimeSeriesID              BusinessType       ControlArea  \
# 0   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 1   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 2   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 3   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 4   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 5   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 6   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 7   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 8   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 9   ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 10  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 11  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 12  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 13  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 14  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 15  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 16  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 17  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 18  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 19  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 20  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 21  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 22  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 23  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 24  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 25  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 26  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 27  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 28  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 29  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 30  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 31  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 32  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 33  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 34  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 35  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 36  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 37  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 38  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 39  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 40  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 41  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 42  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 43  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 44  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 45  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 46  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 47  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
#
#    SettlementDate  SettlementPeriod  ImbalanceQuantity(MAW)  \
# 0      2022-07-01                 1                497.2796
# 1      2022-07-01                 2                269.1110
# 2      2022-07-01                 3                285.8971
# 3      2022-07-01                 4                236.7084
# 4      2022-07-01                 5                -32.1750
# 5      2022-07-01                 6               -101.1726
# 6      2022-07-01                 7                 17.1079
# 7      2022-07-01                 8                 58.9144
# 8      2022-07-01                 9                373.2183
# 9      2022-07-01                10                163.3287
# 10     2022-07-01                11                -34.7279
# 17          Y          Final  ELX-EMFIP-AIMBV-29545748               1
# 18          Y          Final  ELX-EMFIP-AIMBV-29545887               1
# 19          Y          Final  ELX-EMFIP-AIMBV-29546038               1
# 20          Y          Final  ELX-EMFIP-AIMBV-29546185               1
# 21          Y          Final  ELX-EMFIP-AIMBV-29546359               1
# 22          Y          Final  ELX-EMFIP-AIMBV-29546493               1
# 23          Y          Final  ELX-EMFIP-AIMBV-29546647               1
# 24          Y          Final  ELX-EMFIP-AIMBV-29546781               1
# 25          Y          Final  ELX-EMFIP-AIMBV-29546928               1
# 26          Y          Final  ELX-EMFIP-AIMBV-29547075               1
# 27          Y          Final  ELX-EMFIP-AIMBV-29547234               1
# 28          Y          Final  ELX-EMFIP-AIMBV-29547419               1
# 29          Y          Final  ELX-EMFIP-AIMBV-29547592               1
# 30          Y          Final  ELX-EMFIP-AIMBV-29547725               1
# 31          Y          Final  ELX-EMFIP-AIMBV-29547905               1
# 32          Y          Final  ELX-EMFIP-AIMBV-29548068               1
# 33          Y          Final  ELX-EMFIP-AIMBV-29548248               1
# 34          Y          Final  ELX-EMFIP-AIMBV-29548422               1
# 35          Y          Final  ELX-EMFIP-AIMBV-29548590               1
# 36          Y          Final  ELX-EMFIP-AIMBV-29548712               1
# 37          Y          Final  ELX-EMFIP-AIMBV-29548900               1
# 38          Y          Final  ELX-EMFIP-AIMBV-29549019               1
# 39          Y          Final  ELX-EMFIP-AIMBV-29549167               1
# 40          Y          Final  ELX-EMFIP-AIMBV-29549285               1
# 41          Y          Final  ELX-EMFIP-AIMBV-29549462               1
# 42          Y          Final  ELX-EMFIP-AIMBV-29549669               1
# 43          Y          Final  ELX-EMFIP-AIMBV-29549906               1
# 44          Y          Final  ELX-EMFIP-AIMBV-29550053               1
# 45          Y          Final  ELX-EMFIP-AIMBV-29550217               1
# 46          Y          Final  ELX-EMFIP-AIMBV-29550382               1
# 47          Y          Final  ELX-EMFIP-AIMBV-29550517               1
#
#    ImbalanceQuantityDirection  Insufficient_balance_Price_Amount  \
# 0                     SURPLUS                           285.0000
# 1                     SURPLUS                           284.0000
# 2                     SURPLUS                           284.0000
# 3                     SURPLUS                           284.0000
# 4                     DEFICIT                           133.0000
# 5                     DEFICIT                           132.7500
# 6                     SURPLUS                           250.0000
# 7                     SURPLUS                           275.0000
# 8                     SURPLUS                           284.0000
# 9                     SURPLUS                           275.0000
# 10                    DEFICIT                           129.0000
# 11                    DEFICIT                           127.9503
# 12                    SURPLUS                           324.3800
# 13                    SURPLUS                           326.9600
# 14                    SURPLUS                           342.9500
# 15                    SURPLUS                           346.4700
# 16                    SURPLUS                           328.0600
# 17                    SURPLUS                           319.3600
# 18                    SURPLUS                           305.0000
# 19                    SURPLUS                           303.4100
# 20                    SURPLUS                           303.4100
# 21                    DEFICIT                           137.0000
# 22                    SURPLUS                           362.0000
# 23                    SURPLUS                           324.4600
# 24                    DEFICIT                           133.3000
# 25                    DEFICIT                           133.3000
# 26                    SURPLUS                           278.0000
# 27                    SURPLUS                           331.0200
# 28                    SURPLUS                           309.6000
# 29                    DEFICIT                           129.0000
# 30                    SURPLUS                           200.3300
# 31                    SURPLUS                           197.6700
# 32                    SURPLUS                           220.7100
# 33                    DEFICIT                           131.5000
# 34                    DEFICIT                           130.0000
# 35                    DEFICIT                           130.0000
# 36                    SURPLUS                           286.7500
# 37                    SURPLUS                           290.5500
# 38                    SURPLUS                           304.2600
# 39                    SURPLUS                           306.8500
# 40                    DEFICIT                           130.0000
# 41                    SURPLUS                           288.9600
# 42                    SURPLUS                           299.4800
# 43                    SURPLUS                           286.6100
# 44                    SURPLUS                           329.6904
# 45                    SURPLUS                           281.0800
# 46                    SURPLUS                           205.0000
# 47                    SURPLUS                           200.0000
#
#     Excess_balance_Price_Amount
# 0                      285.0000
# 1                      284.0000
# 2                      284.0000
# 3                      284.0000
# 4                      133.0000
# 5                      132.7500
# 6                      250.0000
# 7                      275.0000
# 8                      284.0000
# 9                      275.0000
# 10                     129.0000
# 11                     127.9503
# 12                     324.3800
# 13                     326.9600
# 14                     342.9500
# 15                     346.4700
# 16                     328.0600
# 17                     319.3600
# 18                     305.0000
# 19                     303.4100
# 20                     303.4100
# 21                     137.0000
# 22                     362.0000
# 23                     324.4600
# 24                     133.3000
# 25                     133.3000
# 26                     278.0000
# 27                     331.0200
# 28                     309.6000
# 29                     129.0000
# 30                     200.3300
# 31                     197.6700
# 32                     220.7100
# 33                     131.5000
# 34                     130.0000
# 35                     130.0000
# 36                     286.7500
# 37                     290.5500
# 38                     304.2600
# 39                     306.8500
# 40                     130.0000
# 41                     288.9600
# 42                     299.4800
# 43                     286.6100
# 44                     329.6904
# 45                     281.0800
# 46                     205.0000
# 47                     200.0000

# %%
combined_B1780B1770.dtypes
# Out:
# TimeSeriesID                                 object
# BusinessType                                 object
# ControlArea                                  object
# SettlementDate                       datetime64[ns]
# SettlementPeriod                              int32
# ImbalanceQuantity(MAW)                      float64
# CurveType                                    object
# Resolution                                   object
# DocumentType                                 object
# ProcessType                                  object
# ActiveFlag                                   object
# DocumentStatus                               object
# DocumentID                                   object
# DocumentRevNum                                int32
# ImbalanceQuantityDirection                   object
# Insufficient_balance_Price_Amount           float64
# Excess_balance_Price_Amount                 float64
# dtype: object

# %%
combined_B1780B1770['total_price_invalance'] = np.where(combined_B1780B1770['ImbalanceQuantity(MAW)']< 0,
                                                   abs(combined_B1780B1770['ImbalanceQuantity(MAW)']*combined_B1780B1770['Insufficient_balance_Price_Amount']),
                                                   abs(combined_B1780B1770['ImbalanceQuantity(MAW)']*combined_B1780B1770['Excess_balance_Price_Amount']))
combined_B1780B1770.head()
# Out:
#            TimeSeriesID              BusinessType       ControlArea  \
# 0  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 1  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 2  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 3  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
# 4  ELX-EMFIP-AIMBV-TS-1  Balance energy deviation  10YGB----------A
#
#   SettlementDate  SettlementPeriod  ImbalanceQuantity(MAW)  \
# 0     2022-07-01                 1                497.2796
# 1     2022-07-01                 2                269.1110
# 2     2022-07-01                 3                285.8971
# 3     2022-07-01                 4                236.7084
# 4     2022-07-01                 5                -32.1750
#
#                      CurveType Resolution      DocumentType ProcessType  \
# 0  Sequential fixed size block      PT30M  Imbalance volume    Realised
# 1  Sequential fixed size block      PT30M  Imbalance volume    Realised
# 2  Sequential fixed size block      PT30M  Imbalance volume    Realised
# 3  Sequential fixed size block      PT30M  Imbalance volume    Realised
# 4  Sequential fixed size block      PT30M  Imbalance volume    Realised
#
#   ActiveFlag DocumentStatus                DocumentID  DocumentRevNum  \
# 0          Y          Final  ELX-EMFIP-AIMBV-29543246               1
# 1          Y          Final  ELX-EMFIP-AIMBV-29543378               1
# 2          Y          Final  ELX-EMFIP-AIMBV-29543452               1
# 3          Y          Final  ELX-EMFIP-AIMBV-29543562               1
# 4          Y          Final  ELX-EMFIP-AIMBV-29543658               1
#
#   ImbalanceQuantityDirection  Insufficient_balance_Price_Amount  \
# 0                    SURPLUS                              285.0
# 1                    SURPLUS                              284.0
# 2                    SURPLUS                              284.0
# 3                    SURPLUS                              284.0
# 4                    DEFICIT                              133.0
#
#    Excess_balance_Price_Amount  total_price_invalance
# 0                        285.0            141724.6860
# 1                        284.0             76427.5240
# 2                        284.0             81194.7764
# 3                        284.0             67225.1856
# 4                        133.0              4279.2750

# %% [markdown]
# This new column is created to know the economical impact that each inbalance quantity will have with the balance price

# %% [markdown]
# # <a id='Generateamessage'></a> 3. Generate a message that provides the total daily imbalance cost and the daily imbalance unit rate

# %%
print('total daily imbalance cost:', round(sum(combined_B1780B1770.total_price_invalance),2))
# Out:
# total daily imbalance cost: 1667148.02

# %%
a=(combined_B1780B1770.total_price_invalance)

# %%
b=(np.where(combined_B1780B1770['ImbalanceQuantity(MAW)']< 0,
           combined_B1780B1770['Insufficient_balance_Price_Amount'],combined_B1780B1770['Excess_balance_Price_Amount']))
b
# Out:
# array([285.    , 284.    , 284.    , 284.    , 133.    , 132.75  ,
#        250.    , 275.    , 284.    , 275.    , 129.    , 127.9503,
#        324.38  , 326.96  , 342.95  , 346.47  , 328.06  , 319.36  ,
#        305.    , 303.41  , 303.41  , 137.    , 362.    , 324.46  ,
#        133.3   , 133.3   , 278.    , 331.02  , 309.6   , 129.    ,
#        200.33  , 197.67  , 220.71  , 131.5   , 130.    , 130.    ,
#        286.75  , 290.55  , 304.26  , 306.85  , 130.    , 288.96  ,
#        299.48  , 286.61  , 329.6904, 281.08  , 205.    , 200.    ])

# %%
print('daily imbalance unit rate:', round(statistics.mean(a/b),2))
# Out:
# daily imbalance unit rate: 130.54

# %% [markdown]
# # <a id='Report'></a> 4. Report which Hour had the highest absolute imbalance volumes

# %%
print('The highest absolute imbalance volumes is in the period',max(combined_B1780B1770['SettlementPeriod'][combined_B1780B1770['ImbalanceQuantity(MAW)']==max(combined_B1780B1770['ImbalanceQuantity(MAW)'])]), 'with a value of',max(abs(combined_B1780B1770['ImbalanceQuantity(MAW)'])))
# Out:
# The highest absolute imbalance volumes is in the period 1 with a value of 497.2796

# %% [markdown]
# # <a id='Extraanalysis'></a> 5. Extra analysis or plotting

# %%
# %matplotlib inline

plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
combined_B1780B1770.iloc[:,4:].hist(figsize=(20,10), color = 'mediumslateblue')
pass

# %%
# Plot boxplots
combined_B1780B1770.plot(kind='box', subplots=True, figsize=(20,40),
                      layout=(9,4), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# The circles that are outside the intervals means that it is an outlier. The value is really big or small compared with the dataset

# %%
#Visualizing the data - displot
plot_price = sns.displot(combined_B1780B1770["ImbalanceQuantity(MAW)"], kind="kde", bw_adjust=0.4,label="Quantity")
plt.xlabel('Price / Quantity')
plt.legend();

plot_quantity = sns.displot(combined_B1780B1770["Excess_balance_Price_Amount"], kind="kde", bw_adjust=0.5,label="Excess_balance_Price")
plt.xlabel('Price / Quantity')
plt.legend();

plot_quantity = sns.displot(combined_B1780B1770["total_price_invalance"], kind="kde", bw_adjust=0.5,label="Excess_balance_Price")
plt.xlabel('Total price invalance')
plt.legend();

plot_quantity = sns.displot(combined_B1780B1770[["Excess_balance_Price_Amount","ImbalanceQuantity(MAW)"]], kind="kde", bw_adjust=0.5,label="Excess_balance_Price")
plt.xlabel('Total price invalance')
plt.legend();
#sns.displot(combined_B1780B1770["ImbalanceQuantity(MAW)"], kind="kde", bw_adjust=2)

# %% [markdown]
# For the previous plots density normalization scales the bars so that their areas sum to 1. As a result, the density axis is not directly interpretable.

# %%
sns.jointplot(
    data=combined_B1780B1770,
    x="Excess_balance_Price_Amount", y="ImbalanceQuantity(MAW)", hue="ImbalanceQuantityDirection",
    kind="kde"
)

# %% [markdown]
# From this graph it is visible the differences in the correlation between the Excess_balance_Price_Amount and the ImbalanceQuantity(MAW) divided in grups of positive imbalance and negative imbalance.

# %%
x = combined_B1780B1770["SettlementPeriod"]
y1 = combined_B1780B1770["ImbalanceQuantity(MAW)"]
y2 = combined_B1780B1770["Insufficient_balance_Price_Amount"]
y3 = combined_B1780B1770["Excess_balance_Price_Amount"]

fig, ax1 = plt.subplots()

ax1.plot(x, y1, 'green')
ax2 = ax1.twinx()
ax2.plot(x, y2,'black',label = 'Insufficient_balance_Price_Amount')
ax2.plot(x, y3,'blue',label = 'Excess_balance_Price_Amount')
ax2.plot(np.nan, 'green', label = 'Imbalance_Quantity')


ax1.set_xlabel('SettlementPeriod'+' '+ str(date))
ax1.set_ylabel('Imbalance_Quantity', color='green')
ax2.set_ylabel('Insufficient/Excess_balance_Price_Amount', color='b')

plt.xticks(np.arange(0, len(x)+1, 1))
plt.legend()
#plt.show()

# %% [markdown]
# The black line Insufficient_balance_Price_Amount might shows no data because have the same values than Excess_balance_Price_Amount so the are overlaping

# %% [markdown]
# Reference for PDF export. do make this improvement "https://pyfpdf.readthedocs.io/en/latest/Python3/index.html"

# %% [markdown]
# from fpdf import FPDF
#
# pdf = FPDF()
# # compression is not yet supported in py3k version
# pdf.compress = False
# pdf.add_page()
# # Unicode is not yet supported in the py3k version; use windows-1252 standard font
# pdf.set_font('Arial', '', 14)
# pdf.ln(10)
# pdf.write(5, 'hello world %s áéíóúüñ' % sys.version)
# pdf.image("pyfpdf/tutorial/logo.png", 50, 50)
# pdf.output('py3k.pdf', 'F')
